# %%
import sys
sys.path.append('C:/Users/Lenovo/Desktop/2024_E/tools/')
from CM_dataset_v2 import CM_dataset_v2
from load_array import LoadArray
from mxnet import autograd,gluon,init
from animator import Animator

# %%
CM_data = CM_dataset_v2(1000)

# %%
batch_size = 16
data_loader = LoadArray(CM_data,batch_size)

# %%
model = gluon.nn.Sequential()
model.add(

    # gluon.nn.Dense(64, activation='relu'),
    #gluon.nn.Dense(5),
    gluon.nn.Dense(1)

)
model.initialize(init.Normal(sigma=0.01))

# %%
loss_func = gluon.loss.L2Loss()
optimizer = gluon.Trainer(model.collect_params(),'adam',{'learning_rate':0.00000001})

# %%
best_loss = float(100)

# %%
epochs = 1000
animator = Animator(xlabel='epochs',ylabel='losses',legend=['train'],xlim=[1,epochs])
for epoch in range(epochs):
    epoch_loss = 0
    for feature, label in data_loader:
            with autograd.record():
                l = loss_func(model(feature),label)
                # print(feature,model(feature))
            l.backward()
            optimizer.step(batch_size)
            temp = l.mean().item()
            epoch_loss += temp
    animator.add(epoch+1, (temp,))
    
    #if epoch_loss < best_loss:
     #   best_loss = epoch_loss
      #  model.save_parameters('C:/Users\Lenovo\Desktop\2024_E\model_params')
      #  print('yes')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16488\1345034247.py in <module>
#       3 for epoch in range(epochs):
#       4     epoch_loss = 0
# ----> 5     for feature, label in data_loader:
#       6             with autograd.record():
#       7                 l = loss_func(model(feature),label)
#
# D:\Anaconda\envs\d2l\lib\site-packages\mxnet\gluon\data\dataloader.py in same_process_iter()
#     633             def same_process_iter():
#     634                 for batch in self._batch_sampler:
# --> 635                     ret = self._batchify_fn([self._dataset[idx] for idx in batch])
#     636                     if self._pin_memory:
#     637                         ret = _as_in_context(ret, context.cpu_pinned(self._pin_device_id))
#
# D:\Anaconda\envs\d2l\lib\site-packages\mxnet\gluon\data\dataloader.py in default_batchify_fn(data)
#     147     elif isinstance(data[0], tuple):
#     148         data = zip(*data)
# --> 149         return [default_batchify_fn(i) for i in data]
#     150     else:
#     151         data = np.asarray(data)
#
# D:\Anaconda\envs\d2l\lib\site-packages\mxnet\gluon\data\dataloader.py in <listcomp>(.0)
#     147     elif isinstance(data[0], tuple):
#     148         data = zip(*data)
# --> 149         return [default_batchify_fn(i) for i in data]
#     150     else:
#     151         data = np.asarray(data)
#
# D:\Anaconda\envs\d2l\lib\site-packages\mxnet\gluon\data\dataloader.py in default_batchify_fn(data)
#     151         data = np.asarray(data)
#     152         array_fn = _mx_np.array if is_np_array() else nd.array
# --> 153         return array_fn(data, dtype=data.dtype)
#     154
#     155
#
# D:\Anaconda\envs\d2l\lib\site-packages\mxnet\numpy\multiarray.py in array(object, dtype, ctx)
#    2282         ret[()] = object
#    2283     else:
# -> 2284         ret[:] = object
#    2285     return ret
#    2286
#
# D:\Anaconda\envs\d2l\lib\site-packages\mxnet\numpy\multiarray.py in __setitem__(self, key, value)
#     769             indexing_dispatch_code = get_indexing_dispatch_code(slc_key)
#     770             if indexing_dispatch_code == _NDARRAY_BASIC_INDEXING:
# --> 771                 self._set_nd_basic_indexing(key, value)  # function is inheritated from NDArray class
#     772             elif indexing_dispatch_code == _NDARRAY_EMPTY_TUPLE_INDEXING:
#     773                 pass # no action needed
#
# D:\Anaconda\envs\d2l\lib\site-packages\mxnet\ndarray\ndarray.py in _set_nd_basic_indexing(self, key, value)
#     985                 )
#     986                 value = value.reshape(tmp_shape)
# --> 987                 if isinstance(value, np.generic) or value.shape != self.shape:
#     988                     value = np.broadcast_to(value, self.shape)
#     989                 self._sync_copyfrom(value)
#
# D:\Anaconda\envs\d2l\lib\site-packages\mxnet\numpy\multiarray.py in shape(self)
#    2146     @property
#    2147     def shape(self):
# -> 2148         return super(ndarray, self).shape
#    2149
#    2150     @property
#
# D:\Anaconda\envs\d2l\lib\site-packages\mxnet\ndarray\ndarray.py in shape(self)
#    2403             pdata = ctypes.POINTER(mx_int)()
#    2404             check_call(_LIB.MXNDArrayGetShapeEx(
# -> 2405                 self.handle, ctypes.byref(ndim), ctypes.byref(pdata)))
#    2406         if ndim.value == -1:
#    2407             return None
#
# KeyboardInterrupt:

# %%
model[0].weight.data()
# Out:
# array([[ 0.00625384, -0.01102141, -0.01223782]])

# %%
from mxnet import np, npx
npx.set_np()
feature = np.array([[0.9376,	1,	1





]])
model(feature)
# Out:
# array([[-0.01731834]])
